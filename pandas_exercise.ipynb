# 22          35.0         PIT   ...         NaN     0.511082     0.488918
# 23          42.0         PIT   ...         NaN     0.491891     0.508109
# 24          25.0         PIT   ...         NaN     0.413994     0.586006
# 25          13.0         TEN   ...    1.504306     0.475251     0.524749
# 26          22.0         TEN   ...         NaN     0.448998     0.551002
# 27          20.0         TEN   ...    0.315907     0.470567     0.529433
# 28          22.0         TEN   ...         NaN     0.454633     0.545367
# 29          39.0         TEN   ...    0.201069     0.464664     0.535336
# ..           ...         ...   ...         ...          ...          ...
# 70          22.0         PIT   ...    0.218866     0.537307     0.462693
# 71           9.0         PIT   ...         NaN          NaN          NaN
# 72           0.0         TEN   ...    0.000000     0.589619     0.410381
# 73           7.0         TEN   ...         NaN     0.738386     0.261614
# 74           0.0         PIT   ...         NaN     0.715750     0.284250
# 75           7.0         TEN   ...   -0.988674     0.705351     0.294649
# 76           6.0         TEN   ...    0.845155     0.713310     0.286690
# 77          15.0         TEN   ...         NaN          NaN          NaN
# 78           1.0         PIT   ...    0.000000     0.617306     0.382694
# 79           5.0         PIT   ...         NaN     0.499662     0.500338
# 80           0.0         TEN   ...         NaN     0.519191     0.480809
# 81           7.0         PIT   ...    0.108507     0.525983     0.474017
# 82           6.0         PIT   ...    0.000000     0.527188     0.472812
# 83           8.0         PIT   ...         NaN          NaN          NaN
# 84           0.0         PIT   ...   -0.509636     0.552483     0.447517
# 85           6.0         TEN   ...    0.002546     0.569221     0.430779
# 86           5.0         TEN   ...         NaN     0.560476     0.439524
# 87           9.0         TEN   ...         NaN          NaN          NaN
# 88           0.0         PIT   ...         NaN     0.539795     0.460205
# 89           6.0         PIT   ...   -6.235342     0.532696     0.467304
# 90           1.0         PIT   ...         NaN     0.497962     0.502038
# 91           5.0         TEN   ...         NaN     0.494973     0.505027
# 92          35.0         TEN   ...         NaN     0.478256     0.521744
# 93          42.0         TEN   ...         NaN     0.427334     0.572666
# 94          34.0         TEN   ...    1.204002     0.425697     0.574303
# 95          23.0         PIT   ...         NaN     0.398391     0.601609
# 96          35.0         PIT   ...    0.000000     0.417641     0.582359
# 97           9.0         PIT   ...         NaN     0.574091     0.425909
# 98          37.0         TEN   ...         NaN     0.596120     0.403880
# 99          43.0         TEN   ...         NaN     0.587230     0.412770
#
#     Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0       0.546433      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1       0.551088      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2       0.510793      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3       0.461217      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4       0.558929      0.441071  0.461217  0.097712       NaN       NaN    2009
# 5       0.578453      0.421547  0.441071 -0.019524       NaN       NaN    2009
# 6       0.582881      0.417119  0.421547 -0.004427 -0.010456  0.006029    2009
# 7       0.617544      0.382456  0.417119 -0.034663       NaN       NaN    2009
# 8       0.591489      0.408511  0.382456  0.026054       NaN       NaN    2009
# 9       0.585405      0.414595  0.591489 -0.006084 -0.024526  0.018442    2009
# 10      0.615159      0.384841  0.585405  0.029754 -0.030157  0.059911    2009
# 92      0.427334      0.572666  0.521744  0.050923       NaN       NaN    2009
# 93      0.425697      0.574303  0.572666  0.001637       NaN       NaN    2009
# 94      0.398391      0.601609  0.574303  0.027305 -0.013627  0.040932    2009
# 95      0.417641      0.582359  0.601609 -0.019249       NaN       NaN    2009
# 96      0.574091      0.425909  0.582359 -0.156450 -0.156450  0.000000    2009
# 97      0.596120      0.403880  0.574091  0.022029       NaN       NaN    2009
# 98      0.587230      0.412770  0.596120 -0.008890       NaN       NaN    2009
# 99      0.515547      0.484453  0.587230 -0.071683       NaN       NaN    2009
#
# [100 rows x 102 columns]

# %% [markdown]
# ### 1. 統計所有欄位的 NA 值

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()
missing_values_count[:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# ### 2. 去除 NA 值

# %%
# remove all the rows that contain a missing value
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Date, GameID, Drive, qtr, down, time, TimeUnder, TimeSecs, PlayTimeDiff, SideofField, yrdln, yrdline100, ydstogo, ydsnet, GoalToGo, FirstDown, posteam, DefensiveTeam, desc, PlayAttempted, Yards.Gained, sp, Touchdown, ExPointResult, TwoPointConv, DefTwoPoint, Safety, Onsidekick, PuntResult, PlayType, Passer, Passer_ID, PassAttempt, PassOutcome, PassLength, AirYards, YardsAfterCatch, QBHit, PassLocation, InterceptionThrown, Interceptor, Rusher, Rusher_ID, RushAttempt, RunLocation, RunGap, Receiver, Receiver_ID, Reception, ReturnResult, Returner, BlockingPlayer, Tackler1, Tackler2, FieldGoalResult, FieldGoalDistance, Fumble, RecFumbTeam, RecFumbPlayer, Sack, Challenge.Replay, ChalReplayResult, Accepted.Penalty, PenalizedTeam, PenaltyType, PenalizedPlayer, Penalty.Yards, PosTeamScore, DefTeamScore, ScoreDiff, AbsScoreDiff, HomeTeam, AwayTeam, Timeout_Indicator, Timeout_Team, posteam_timeouts_pre, HomeTimeouts_Remaining_Pre, AwayTimeouts_Remaining_Pre, HomeTimeouts_Remaining_Post, AwayTimeouts_Remaining_Post, No_Score_Prob, Opp_Field_Goal_Prob, Opp_Safety_Prob, Opp_Touchdown_Prob, Field_Goal_Prob, Safety_Prob, Touchdown_Prob, ExPoint_Prob, TwoPoint_Prob, ExpPts, EPA, airEPA, yacEPA, Home_WP_pre, Away_WP_pre, Home_WP_post, Away_WP_post, Win_Prob, WPA, airWPA, ...]
# Index: []
#
# [0 rows x 102 columns]

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = df.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp   ...    Timeout_Indicator  Timeout_Team  \
# 0              1            39   0   ...                    0          None
# 1              1             5   0   ...                    0          None
# 2              1            -3   0   ...                    0          None
# 3              1             0   0   ...                    0          None
# 4              1             0   0   ...                    0          None
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre AwayTimeouts_Remaining_Pre  \
# 0                     3                          3                          3
# 1                     3                          3                          3
# 2                     3                          3                          3
# 3                     3                          3                          3
# 4                     3                          3                          3
#
#    HomeTimeouts_Remaining_Post  AwayTimeouts_Remaining_Post  ExPoint_Prob  \
# 0                            3                            3           0.0
# 1                            3                            3           0.0
# 2                            3                            3           0.0
# 3                            3                            3           0.0
# 4                            3                            3           0.0
#
#    TwoPoint_Prob  Season
# 0            0.0    2009
# 1            0.0    2009
# 2            0.0    2009
# 3            0.0    2009
# 4            0.0    2009
#
# [5 rows x 41 columns]

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % df.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 102
#
# Columns with na's dropped: 41

# %% [markdown]
# ### 3. 資料自動填補值的操作

# %%
# get a small subset of the NFL dataset
subset_df = df.loc[:, 'EPA':'Season'].head()
subset_df
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
# replace all NA's with 0
subset_df.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the reamining na's with 0
subset_df.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %% [markdown]
# # 時間日期處理

# %%
import pandas as pd

df = pd.read_csv('data/catalog.csv')
df.shape
# Out:
# (1693, 23)

# %%
df.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  \
# 0       Virginia       16000       Cherry Hill   3.40765
# 1           Ohio       17288  New Philadelphia   3.33522
# 2   Pennsylvania       15930       Wilkinsburg   2.91977
# 3         Quebec       42786       Châteauguay   2.98682
# 4       Kentucky        6903         Pikeville   5.66542
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# 1  (40.517499999999998, -81.430499999999995)    Landslide           Landslide
# 2             (40.4377, -79.915999999999997)    Landslide           Landslide
# 3  (45.322600000000001, -73.777100000000004)    Landslide  Riverbank collapse
# 4  (37.432499999999997, -82.493099999999998)    Landslide           Landslide
#
#   landslide_size   trigger storm_name injuries fatalities  \
# 0          Small      Rain        NaN      NaN        NaN
# 1          Small      Rain        NaN      NaN        NaN
# 2          Small      Rain        NaN      NaN        NaN
# 3          Small      Rain        NaN      NaN        NaN
# 4          Small  Downpour        NaN      NaN        0.0
#
#                   source_name  \
# 0                  NBC 4 news
# 1              Canton Rep.com
# 2  The Pittsburgh Channel.com
# 3                   Le Soleil
# 4      Matthew Crawford (KGS)
#
#                                          source_link
# 0      http://www.nbc4.com/news/11186871/detail.html
# 1  http://www.cantonrep.com/index.php?ID=345054&C...
# 2  https://web.archive.org/web/20080423132842/htt...
# 3  http://www.hebdos.net/lsc/edition162007/articl...
# 4                                                NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 1. 時間日期欄位轉換

# %%
# print the first few rows of the date column
print(df['date'].head(10))
# Out:
# 0     3/2/07
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# 4    4/15/07
# 5    4/20/07
# 6    4/24/07
# 7    5/21/07
# 8    6/27/07
# 9    6/27/07
# Name: date, dtype: object

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
# convert to datetime format
df['date_parsed'] = pd.to_datetime(df['date'], format = "%m/%d/%y")

# %%
print(df['date_parsed'].head(10))
# Out:
# 0   2007-03-02
# 1   2007-03-22
# 2   2007-04-06
# 3   2007-04-14
# 4   2007-04-15
# 5   2007-04-20
# 6   2007-04-24
# 7   2007-05-21
# 8   2007-06-27
# 9   2007-06-27
# Name: date_parsed, dtype: datetime64[ns]

# %%
# set index to date
df = df.set_index(df['date_parsed'])
df =df.sort_index()
df = df[df.index.notnull()]
df.head(10)
# Out:
#                id     date   time continent_code   country_name country_code  \
# date_parsed
# 2007-03-02     34   3/2/07  Night            NaN  United States           US
# 2007-03-22     42  3/22/07    NaN            NaN  United States           US
# 2007-04-06     56   4/6/07    NaN            NaN  United States           US
# 2007-04-13   7399  4/13/07    NaN            NaN  United States           US
# 2007-04-14     59  4/14/07    NaN            NaN         Canada           CA
# 2007-04-15     61  4/15/07    NaN            NaN  United States           US
# 2007-04-20     64  4/20/07    NaN            NaN  United States           US
# 2007-04-24     67  4/24/07    NaN            NaN  United States           US
# 2007-05-21     77  5/21/07    NaN             SA       Colombia           CO
# 2007-06-01   6253   6/1/07    NaN            NaN  United States           US
#
#             state/province  population         city/town  distance  \
# date_parsed
# 2007-03-02        Virginia       16000       Cherry Hill   3.40765
# 2007-03-22            Ohio       17288  New Philadelphia   3.33522
# 2007-04-06    Pennsylvania       15930       Wilkinsburg   2.91977
# 2007-04-13    Pennsylvania        3165         Homestead   3.74490
# 2007-04-14          Quebec       42786       Châteauguay   2.98682
# 2007-04-15        Kentucky        6903         Pikeville   5.66542
# 2007-04-20        Kentucky        6903         Pikeville   0.23715
# 2007-04-24    South Dakota        2540      Dakota Dunes   2.48033
# 2007-05-21       Risaralda      440118           Pereira   0.62022
# 2007-06-01        Colorado        1864            Granby   5.53226
#
#                 ...      hazard_type      landslide_type  landslide_size  \
# date_parsed     ...
# 2007-03-02      ...        Landslide           Landslide           Small
# 2007-03-22      ...        Landslide           Landslide           Small
# 2007-04-06      ...        Landslide           Landslide           Small
# 2007-04-13      ...        Landslide           Landslide          Medium
# 2007-04-14      ...        Landslide  Riverbank collapse           Small
# 2007-04-15      ...        Landslide           Landslide           Small
# 2007-04-20      ...        Landslide           Landslide           Small
# 2007-04-24      ...        Landslide           Landslide           Small
# 2007-05-21      ...        Landslide            Mudslide           Large
# 2007-06-01      ...        Landslide           Landslide          Medium
#
#               trigger storm_name injuries fatalities  \
# date_parsed
# 2007-03-02       Rain        NaN      NaN        NaN
# 2007-03-22       Rain        NaN      NaN        NaN
# 2007-04-06       Rain        NaN      NaN        NaN
# 2007-04-13    Unknown        NaN      0.0        0.0
# 2007-04-14       Rain        NaN      NaN        NaN
# 2007-04-15   Downpour        NaN      NaN        0.0
# 2007-04-20       Rain        NaN      NaN        NaN
# 2007-04-24       Rain        NaN      NaN        NaN
# 2007-05-21       Rain        NaN      NaN       13.0
# 2007-06-01    Unknown        NaN      0.0        0.0
#
#                             source_name  \
# date_parsed
# 2007-03-02                   NBC 4 news
# 2007-03-22               Canton Rep.com
# 2007-04-06   The Pittsburgh Channel.com
# 2007-04-13                         WTAE
# 2007-04-14                    Le Soleil
# 2007-04-15       Matthew Crawford (KGS)
# 2007-04-20    Applalachain news-express
# 2007-04-24          Sioux City Journnal
# 2007-05-21       Reuters - AlertNet.org
# 2007-06-01                  Sky-Hi News
#
#                                                    source_link  date_parsed
# date_parsed
# 2007-03-02       http://www.nbc4.com/news/11186871/detail.html   2007-03-02
# 2007-03-22   http://www.cantonrep.com/index.php?ID=345054&C...   2007-03-22
# 2007-04-06   https://web.archive.org/web/20080423132842/htt...   2007-04-06
# 2007-04-13   https://web.archive.org/web/20080423132842/htt...   2007-04-13
# 2007-04-14   http://www.hebdos.net/lsc/edition162007/articl...   2007-04-14
# 2007-04-15                                                 NaN   2007-04-15
# 2007-04-20   http://www.news-expressky.com/articles/2007/04...   2007-04-20
# 2007-04-24   http://www.siouxcityjournal.com/articles/2007/...   2007-04-24
# 2007-05-21   http://www.reuters.com/news/video/videoStory?v...   2007-05-21
# 2007-06-01   http://www.skyhidailynews.com/news/13393638-11...   2007-06-01
#
# [10 rows x 24 columns]

# %%
# select row bt date
df["2007-03":"2007-05"]
# Out:
#                id     date   time continent_code   country_name country_code  \
# date_parsed
# 2007-03-02     34   3/2/07  Night            NaN  United States           US
# 2007-03-22     42  3/22/07    NaN            NaN  United States           US
# 2007-04-06     56   4/6/07    NaN            NaN  United States           US
# 2007-04-13   7399  4/13/07    NaN            NaN  United States           US
# 2007-04-14     59  4/14/07    NaN            NaN         Canada           CA
# 2007-04-15     61  4/15/07    NaN            NaN  United States           US
# 2007-04-20     64  4/20/07    NaN            NaN  United States           US
# 2007-04-24     67  4/24/07    NaN            NaN  United States           US
# 2007-05-21     77  5/21/07    NaN             SA       Colombia           CO
#
#             state/province  population         city/town  distance  \
# date_parsed
# 2007-03-02        Virginia       16000       Cherry Hill   3.40765
# 2007-03-22            Ohio       17288  New Philadelphia   3.33522
# 2007-04-06    Pennsylvania       15930       Wilkinsburg   2.91977
# 2007-04-13    Pennsylvania        3165         Homestead   3.74490
# 2007-04-14          Quebec       42786       Châteauguay   2.98682
# 2007-04-15        Kentucky        6903         Pikeville   5.66542
# 2007-04-20        Kentucky        6903         Pikeville   0.23715
# 2007-04-24    South Dakota        2540      Dakota Dunes   2.48033
# 2007-05-21       Risaralda      440118           Pereira   0.62022
#
#                 ...      hazard_type      landslide_type  landslide_size  \
# date_parsed     ...
# 2007-03-02      ...        Landslide           Landslide           Small
# 2007-03-22      ...        Landslide           Landslide           Small
# 2007-04-06      ...        Landslide           Landslide           Small
# 2007-04-13      ...        Landslide           Landslide          Medium
# 2007-04-14      ...        Landslide  Riverbank collapse           Small
# 2007-04-15      ...        Landslide           Landslide           Small
# 2007-04-20      ...        Landslide           Landslide           Small
# 2007-04-24      ...        Landslide           Landslide           Small
# 2007-05-21      ...        Landslide            Mudslide           Large
#
#               trigger storm_name injuries fatalities  \
# date_parsed
# 2007-03-02       Rain        NaN      NaN        NaN
# 2007-03-22       Rain        NaN      NaN        NaN
# 2007-04-06       Rain        NaN      NaN        NaN
# 2007-04-13    Unknown        NaN      0.0        0.0
# 2007-04-14       Rain        NaN      NaN        NaN
# 2007-04-15   Downpour        NaN      NaN        0.0
# 2007-04-20       Rain        NaN      NaN        NaN
# 2007-04-24       Rain        NaN      NaN        NaN
# 2007-05-21       Rain        NaN      NaN       13.0
#
#                             source_name  \
# date_parsed
# 2007-03-02                   NBC 4 news
# 2007-03-22               Canton Rep.com
# 2007-04-06   The Pittsburgh Channel.com
# 2007-04-13                         WTAE
# 2007-04-14                    Le Soleil
# 2007-04-15       Matthew Crawford (KGS)
# 2007-04-20    Applalachain news-express
# 2007-04-24          Sioux City Journnal
# 2007-05-21       Reuters - AlertNet.org
#
#                                                    source_link  date_parsed
# date_parsed
# 2007-03-02       http://www.nbc4.com/news/11186871/detail.html   2007-03-02
# 2007-03-22   http://www.cantonrep.com/index.php?ID=345054&C...   2007-03-22
# 2007-04-06   https://web.archive.org/web/20080423132842/htt...   2007-04-06
# 2007-04-13   https://web.archive.org/web/20080423132842/htt...   2007-04-13
# 2007-04-14   http://www.hebdos.net/lsc/edition162007/articl...   2007-04-14
# 2007-04-15                                                 NaN   2007-04-15
# 2007-04-20   http://www.news-expressky.com/articles/2007/04...   2007-04-20
# 2007-04-24   http://www.siouxcityjournal.com/articles/2007/...   2007-04-24
# 2007-05-21   http://www.reuters.com/news/video/videoStory?v...   2007-05-21
#
# [9 rows x 24 columns]

# %% [markdown]
# ### 2. 時間序列解析度操作

# %%
# select sub df
df = df[~df.index.duplicated(keep='first')]
sub_df = df.loc[:,['population', 'distance']].head(10)
sub_df
# Out:
#              population  distance
# date_parsed
# 2007-03-02        16000   3.40765
# 2007-03-22        17288   3.33522
# 2007-04-06        15930   2.91977
# 2007-04-13         3165   3.74490
# 2007-04-14        42786   2.98682
# 2007-04-15         6903   5.66542
# 2007-04-20         6903   0.23715
# 2007-04-24         2540   2.48033
# 2007-05-21       440118   0.62022
# 2007-06-01         1864   5.53226

# %%
# resample interval to 1 day.
sub_df.resample('1D').asfreq()
# Out:
#              population  distance
# date_parsed
# 2007-03-02      16000.0   3.40765
# 2007-03-03          NaN       NaN
# 2007-03-04          NaN       NaN
# 2007-03-05          NaN       NaN
# 2007-03-06          NaN       NaN
# 2007-03-07          NaN       NaN
# 2007-03-08          NaN       NaN
# 2007-03-09          NaN       NaN
# 2007-03-10          NaN       NaN
# 2007-03-11          NaN       NaN
# 2007-03-12          NaN       NaN
# 2007-03-13          NaN       NaN
# 2007-03-14          NaN       NaN
# 2007-03-15          NaN       NaN
# 2007-03-16          NaN       NaN
# 2007-03-17          NaN       NaN
# 2007-03-18          NaN       NaN
# 2007-03-19          NaN       NaN
# 2007-03-20          NaN       NaN
# 2007-03-21          NaN       NaN
# 2007-03-22      17288.0   3.33522
# 2007-03-23          NaN       NaN
# 2007-03-24          NaN       NaN
# 2007-03-25          NaN       NaN
# 2007-03-26          NaN       NaN
# 2007-03-27          NaN       NaN
# 2007-03-28          NaN       NaN
# 2007-03-29          NaN       NaN
# 2007-03-30          NaN       NaN
# 2007-03-31          NaN       NaN
# ...                 ...       ...
# 2007-05-03          NaN       NaN
# 2007-05-04          NaN       NaN
# 2007-05-05          NaN       NaN
# 2007-05-06          NaN       NaN
# 2007-05-07          NaN       NaN
# 2007-05-08          NaN       NaN
# 2007-05-09          NaN       NaN
# 2007-05-10          NaN       NaN
# 2007-05-11          NaN       NaN
# 2007-05-12          NaN       NaN
# 2007-05-13          NaN       NaN
# 2007-05-14          NaN       NaN
# 2007-05-15          NaN       NaN
# 2007-05-16          NaN       NaN
# 2007-05-17          NaN       NaN
# 2007-05-18          NaN       NaN
# 2007-05-19          NaN       NaN
# 2007-05-20          NaN       NaN
# 2007-05-21     440118.0   0.62022
# 2007-05-22          NaN       NaN
# 2007-05-23          NaN       NaN
# 2007-05-24          NaN       NaN
# 2007-05-25          NaN       NaN
# 2007-05-26          NaN       NaN
# 2007-05-27          NaN       NaN
# 2007-05-28          NaN       NaN
# 2007-05-29          NaN       NaN
# 2007-05-30          NaN       NaN
# 2007-05-31          NaN       NaN
# 2007-06-01       1864.0   5.53226
#
# [92 rows x 2 columns]

# %%
# bfill
sub_df.resample('1D').bfill()
# Out:
#              population  distance
# date_parsed
# 2007-03-02        16000   3.40765
# 2007-03-03        17288   3.33522
# 2007-03-04        17288   3.33522
# 2007-03-05        17288   3.33522
# 2007-03-06        17288   3.33522
# 2007-03-07        17288   3.33522
# 2007-03-08        17288   3.33522
# 2007-03-09        17288   3.33522
# 2007-03-10        17288   3.33522
# 2007-03-11        17288   3.33522
# 2007-03-12        17288   3.33522
# 2007-03-13        17288   3.33522
# 2007-03-14        17288   3.33522
# 2007-03-15        17288   3.33522
# 2007-03-16        17288   3.33522
# 2007-03-17        17288   3.33522
# 2007-03-18        17288   3.33522
# 2007-03-19        17288   3.33522
# 2007-03-20        17288   3.33522
# 2007-03-21        17288   3.33522
# 2007-03-22        17288   3.33522
# 2007-03-23        15930   2.91977
# 2007-03-24        15930   2.91977
# 2007-03-25        15930   2.91977
# 2007-03-26        15930   2.91977
# 2007-03-27        15930   2.91977
# 2007-03-28        15930   2.91977
# 2007-03-29        15930   2.91977
# 2007-03-30        15930   2.91977
# 2007-03-31        15930   2.91977
# ...                 ...       ...
# 2007-05-03       440118   0.62022
# 2007-05-04       440118   0.62022
# 2007-05-05       440118   0.62022
# 2007-05-06       440118   0.62022
# 2007-05-07       440118   0.62022
# 2007-05-08       440118   0.62022
# 2007-05-09       440118   0.62022
# 2007-05-10       440118   0.62022
# 2007-05-11       440118   0.62022
# 2007-05-12       440118   0.62022
# 2007-05-13       440118   0.62022
# 2007-05-14       440118   0.62022
# 2007-05-15       440118   0.62022
# 2007-05-16       440118   0.62022
# 2007-05-17       440118   0.62022
# 2007-05-18       440118   0.62022
# 2007-05-19       440118   0.62022
# 2007-05-20       440118   0.62022
# 2007-05-21       440118   0.62022
# 2007-05-22         1864   5.53226
# 2007-05-23         1864   5.53226
# 2007-05-24         1864   5.53226
# 2007-05-25         1864   5.53226
# 2007-05-26         1864   5.53226
# 2007-05-27         1864   5.53226
# 2007-05-28         1864   5.53226
# 2007-05-29         1864   5.53226
# 2007-05-30         1864   5.53226
# 2007-05-31         1864   5.53226
# 2007-06-01         1864   5.53226
#
# [92 rows x 2 columns]

# %% [markdown]
# # 資料分割選擇與合併

# %% [markdown]
# ## 1. .iloc vs loc

# %% [markdown]
# ![](http://104.236.88.249/wp-content/uploads/2016/10/Pandas-selections-and-indexing.png)

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(4,4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0 -0.400363  1.141485  0.821102  0.237137
# 1 -0.122230  0.293221 -1.318223  0.765636
# 2  1.530837 -0.730529 -0.614539 -0.639149
# 3 -0.201329  1.279875  1.875210  0.466313

# %%
# iloc index based index slelction
df.iloc[:2,[0,2]]
# Out:
#           a         c
# 0  1.574904 -0.263963
# 1 -1.377969  2.188388

# %%
# loc label based index slelction
df.loc[:1,['a', 'c']]
# Out:
#           a         c
# 0  1.574904 -0.263963
# 1 -1.377969  2.188388

# %% [markdown]
# ### 兩者容易混淆之處

# %%
df = pd.DataFrame(np.random.randn(4,4), columns=['a', 'b', 'c', 'd'], index=[0, 1, 8, 3])
df
# Out:
#           a         b         c         d
# 0  1.574904 -0.008773 -0.263963 -0.806723
# 1 -1.377969  0.754676  2.188388 -0.243525
# 8  0.328553 -1.505490 -0.161446  1.653918
# 3  0.565548  0.072182 -2.720340  0.950584

# %% [markdown]
# ### 選取 3, 4 列作法:

# %%
# iloc
df.iloc[2:4,:]
# Out:
#           a         b         c         d
# 8  0.328553 -1.505490 -0.161446  1.653918
# 3  0.565548  0.072182 -2.720340  0.950584

# %%
# loc
df.loc[2:4,:]

# %%
# loc 正確 index 取法
df.loc[8:3,:]
# Out:
#           a         b         c         d
# 8  0.328553 -1.505490 -0.161446  1.653918
# 3  0.565548  0.072182 -2.720340  0.950584

# %% [markdown]
# ## 2. 合併 concat

# %%
df1 = pd.DataFrame(np.random.randn(4,5), columns=['a', 'b', 'c', 'd', 'e'])
df2 = pd.DataFrame(np.random.randn(6,4), columns=['g', 'y', 'k', 'f'])
print(df1.shape)
print(df2.shape)
# Out:
# (4, 5)
# (6, 4)

# %%
# 列方向合併 (上下)
merge_df = pd.concat([df1, df2], axis=0)
merge_df
# Out:
#           a         b         c         d         e         f         g  \
# 0 -0.919846 -0.495675  1.911603  1.309731  0.399571       NaN       NaN
# 1 -0.494185 -1.246625  0.074627 -0.725263  0.814656       NaN       NaN
# 2 -1.453585  0.908129  1.105333  0.108686  0.420912       NaN       NaN
# 3  0.763184 -0.427747  0.844336 -0.915844 -1.432858       NaN       NaN
# 0       NaN       NaN       NaN       NaN       NaN  0.918278  1.002602
# 1       NaN       NaN       NaN       NaN       NaN  1.493787  1.015558
# 2       NaN       NaN       NaN       NaN       NaN  0.080813  0.035731
# 3       NaN       NaN       NaN       NaN       NaN -0.402318 -2.018605
# 4       NaN       NaN       NaN       NaN       NaN  0.741613 -0.415160
# 5       NaN       NaN       NaN       NaN       NaN  0.810024  1.609868
#
#           k         y
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 0 -0.174406 -0.910231
# 1 -0.517051 -0.790699
# 2 -1.578405  0.119997
# 3  0.268080 -0.988506
# 4 -0.330801  0.301276
# 5  0.397550 -0.338401

# %%
print(merge_df.shape)
# Out:
# (10, 9)

# %%
# 行方向合併 (左右)
merge_df = pd.concat([df1, df2], axis=1)
merge_df
# Out:
#           a         b         c         d         e         g         y  \
# 0 -0.919846 -0.495675  1.911603  1.309731  0.399571  1.002602 -0.910231
# 1 -0.494185 -1.246625  0.074627 -0.725263  0.814656  1.015558 -0.790699
# 2 -1.453585  0.908129  1.105333  0.108686  0.420912  0.035731  0.119997
# 3  0.763184 -0.427747  0.844336 -0.915844 -1.432858 -2.018605 -0.988506
# 4       NaN       NaN       NaN       NaN       NaN -0.415160  0.301276
# 5       NaN       NaN       NaN       NaN       NaN  1.609868 -0.338401
#
#           k         f
# 0 -0.174406  0.918278
# 1 -0.517051  1.493787
# 2 -1.578405  0.080813
# 3  0.268080 -0.402318
# 4 -0.330801  0.741613
# 5  0.397550  0.810024

# %%
merge_df.shape
# Out:
# (6, 9)

# %% [markdown]
# ## reference
#
# 1. https://www.kaggle.com/rtatman/data-cleaning-challenge-handling-missing-values
# 2. http://www.learningthemachine.com/2017/08/20/review-pandas-loc-vs-iloc/
